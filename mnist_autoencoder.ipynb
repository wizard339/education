# %% [markdown]
# <a href="https://colab.research.google.com/github/wizard339/education/blob/main/mnist_autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.models as M

print(tf.__version__)
# Out:
# 2.9.2

# %%
# Проверяем что у нас работает GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#GPU count and name
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-5e9f82b3-86e2-35f1-68e7-e1e8610f3390)

# %% [markdown]
# ## Load and preprocess MNIST dataset

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.mnist.load_data()

train_x = train_x.reshape(-1, 28, 28, 1).astype(np.float32) / 255.
test_x = test_x.reshape(-1, 28, 28, 1).astype(np.float32) / 255.

print(train_x.shape, train_x.dtype)
print(test_x.shape, test_x.dtype)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# (60000, 28, 28, 1) float32
# (10000, 28, 28, 1) float32

# %% [markdown]
# ## Draw MNIST examples

# %%
def plot_digits(samples):
    fig = plt.figure(figsize=(10, 6))
    num = samples.shape[0]
    for j in range(num):
        ax = fig.add_subplot(4, 8, j+1)
        ax.imshow(samples[j,:,:,0], cmap='gray')
        plt.xticks([]), plt.yticks([])
    plt.show()
    
plot_digits(train_x[:32, ...])

# %% [markdown]
# ## Create Autoencoder model: Encoder and Decoder

# %%
train_x.shape[1:]
# Out:
# (28, 28, 1)

# %%
encoder = M.Sequential([
    #L.ZeroPadding2D((2, 2)),
    L.Conv2D(16, (3, 3), activation='relu', padding='same', input_shape=train_x.shape[1:]),
    L.MaxPooling2D((2, 2), padding='same'),
    L.Conv2D(8, (3, 3), padding='same', activation='relu'),
    L.MaxPooling2D((2, 2), padding='same'),
    L.Conv2D(8, (3, 3), strides=(2,2), activation='relu', padding='same'),
    # Flatten encoding for visualization
    L.Flatten(),
    L.Reshape((4, 4, 8)),
])

decoder = M.Sequential([
    L.Conv2D(8, (3, 3), activation='relu', padding='same', input_shape=(4, 4, 8)),
    L.UpSampling2D((2, 2)),
    L.Conv2D(8, (3, 3), padding='same', activation='relu'),
    L.UpSampling2D((2, 2)),
    L.Conv2D(8, (3, 3), padding='same', activation='relu'),
    L.UpSampling2D((2, 2)),
    L.Conv2D(1, (3, 3), padding='same', activation='sigmoid'),
    L.Cropping2D((2, 2))
])

autoencoder = M.Sequential([encoder, decoder])

autoencoder.compile(optimizer='RMSprop', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 4, 4, 8)           1904
#
#  sequential_1 (Sequential)   (None, 28, 28, 1)         1825
#
# =================================================================
# Total params: 3,729
# Trainable params: 3,729
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Autoencoder training

# %%
NUM_EPOCHS = 25
BATCH_SIZE = 128

# %%
autoencoder.fit(train_x, train_x,
                epochs=NUM_EPOCHS,
                batch_size=BATCH_SIZE,
                shuffle=True,
                validation_data=(test_x, test_x))
# Out:
# Epoch 1/25
# 469/469 [==============================] - 11s 7ms/step - loss: 0.0489 - val_loss: 0.0326
# Epoch 2/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0284 - val_loss: 0.0238
# Epoch 3/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0230 - val_loss: 0.0212
# Epoch 4/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0203 - val_loss: 0.0178
# Epoch 5/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0186 - val_loss: 0.0168
# Epoch 6/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0174 - val_loss: 0.0168
# Epoch 7/25
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0165 - val_loss: 0.0166
# Epoch 8/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0157 - val_loss: 0.0156
# Epoch 9/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0150 - val_loss: 0.0143
# Epoch 10/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0145 - val_loss: 0.0142
# Epoch 11/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0140 - val_loss: 0.0139
# Epoch 12/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0136 - val_loss: 0.0129
# Epoch 13/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0132 - val_loss: 0.0129
# Epoch 14/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0129 - val_loss: 0.0116
# Epoch 15/25
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 16/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0123 - val_loss: 0.0122
# Epoch 17/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0120 - val_loss: 0.0113
# Epoch 18/25
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0118 - val_loss: 0.0114
# Epoch 19/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0115 - val_loss: 0.0113
# Epoch 20/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0113 - val_loss: 0.0107
# Epoch 21/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0111 - val_loss: 0.0106
# Epoch 22/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 23/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0100
# Epoch 24/25
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0106 - val_loss: 0.0097
# Epoch 25/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0105 - val_loss: 0.0101

# %% [markdown]
# ## Autoencoder inference test

# %%
text_x_pred = autoencoder.predict(test_x[0:8])

plot_digits(test_x[0:8])
plot_digits(text_x_pred)
# Out:
# 1/1 [==============================] - 0s 230ms/step

# %% [markdown]
# Посмотрим как происходит транформация по этапам

# %%
num_images = 10
random_test_images = np.random.randint(test_x.shape[0], size=num_images)

encoded_imgs = encoder.predict(test_x)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 1s 1ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.figure(figsize=(18, 4))

for i, image_idx in enumerate(random_test_images):
    # plot original image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(test_x[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # plot encoded image
    ax = plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(encoded_imgs[image_idx].reshape(16, 8))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot reconstructed image
    ax = plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(decoded_imgs[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Decoder inference test: random inputs

# %%
plot_digits(decoder.predict(np.random.rand(8, 4, 4, 8) * 5))
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# ## Prepare noisy dataset (for Denoising AE)

# %%
def add_noise(x):
    return np.clip(x + 0.5 + 0.5*np.random.randn(*x.shape), 0, 1)

train_x_noise = add_noise(train_x)
test_x_noise = add_noise(test_x)

plot_digits(train_x_noise[:8])

# %% [markdown]
# ## Denoising Autoencoder training

# %%
NUM_EPOCHS = 25
BATCH_SIZE = 128

autoencoder.fit(train_x_noise, train_x,
                epochs=NUM_EPOCHS,
                batch_size=BATCH_SIZE,
                shuffle=True,
                validation_data=(test_x_noise, test_x))
# Out:
# Epoch 1/25
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0331 - val_loss: 0.0278
# Epoch 2/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0274 - val_loss: 0.0248
# Epoch 3/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0258 - val_loss: 0.0252
# Epoch 4/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0246 - val_loss: 0.0239
# Epoch 5/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0237 - val_loss: 0.0231
# Epoch 6/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0230 - val_loss: 0.0226
# Epoch 7/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0224 - val_loss: 0.0213
# Epoch 8/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0220 - val_loss: 0.0209
# Epoch 9/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0216 - val_loss: 0.0213
# Epoch 10/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0213 - val_loss: 0.0205
# Epoch 11/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0210 - val_loss: 0.0203
# Epoch 12/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0208 - val_loss: 0.0207
# Epoch 13/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0206 - val_loss: 0.0195
# Epoch 14/25
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0204 - val_loss: 0.0210
# Epoch 15/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0203 - val_loss: 0.0192
# Epoch 16/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0201 - val_loss: 0.0202
# Epoch 17/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0200 - val_loss: 0.0199
# Epoch 18/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0199 - val_loss: 0.0204
# Epoch 19/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0198 - val_loss: 0.0209
# Epoch 20/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0197 - val_loss: 0.0199
# Epoch 21/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0196 - val_loss: 0.0189
# Epoch 22/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0195 - val_loss: 0.0187
# Epoch 23/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0195 - val_loss: 0.0189
# Epoch 24/25
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0194 - val_loss: 0.0197
# Epoch 25/25
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0193 - val_loss: 0.0186

# %% [markdown]
# ## Denoising Autoencoder inference test

# %%
text_x_pred = autoencoder.predict(test_x_noise[0:8])

plot_digits(test_x_noise[0:8])
plot_digits(text_x_pred)
# Out:
# 1/1 [==============================] - 0s 16ms/step

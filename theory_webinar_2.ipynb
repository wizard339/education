# %% [markdown]
# <a href="https://colab.research.google.com/github/wizard339/education/blob/main/theory_webinar_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Функции

# %% [markdown]
# ## 1. Определение функции

# %% [markdown]
# **Функция** – однозначное соответствие между элементами двух множеств.
# Однозначное – каждому элементу из $x$ соответствует один элемент из $y$
# $$y = f(x)$$

# %% [markdown]
# Область определения функции – $D(f)$. Множество значений $x$.
# Область значений функции – $E(f)$. Множество значений $y$.

# %% [markdown]
# Это функция?
#
# $x^2 + y^2 = r^2$

# %%
circle = plt.Circle((0.5, 0.5), 0.5, color='r', fill=None)
plt.figure(figsize=(5, 5))
plt.gcf().gca().add_artist(circle)

# %% [markdown]
# Функции могут быть от одной или нескольких переменных.

# %%
def draw_func(f):
    x = np.linspace(-10, 10, 1000)
    y = f(x)
    fig, ax = plt.subplots(figsize=(6, 5))
    ax.plot(x, y)

# %%
draw_func(lambda x: x ** 2)

# %% [markdown]
# ## 2. Примеры функций

# %% [markdown]
# Степенная функция $x^k$

# %%
draw_func(lambda x: x ** 3)

# %%
draw_func(lambda x: x ** 21)

# %% [markdown]
# Тригонометрические функции:

# %%
draw_func(lambda x: np.cos(x))

# %% [markdown]
# Показательные функции ($e^x$ и другие) и логарифмы ($log(x)$):

# %%
draw_func(lambda x: 3 ** x)

# %%
draw_func(lambda x: np.log10(x))
# Out:
# <ipython-input-9-0fc09b0c26e3>:1: RuntimeWarning: invalid value encountered in log10
#   draw_func(lambda x: np.log10(x))

# %% [markdown]
# Суперпозиция функций:

# %%
draw_func(lambda x: np.sin(np.log(x)))
# Out:
# <ipython-input-10-3119a6a484d7>:1: RuntimeWarning: invalid value encountered in log
#   draw_func(lambda x: np.sin(np.log(x)))

# %% [markdown]
# ## 3. Производная

# %% [markdown]
# Производная – скорость изменения функции.
# Определение – предел приращения функции к приращению ее аргумента при стремлении приращения аргумента к 0:
#
# $$f'(x) = lim_{\Delta x \rightarrow 0} \frac{\Delta f(x)}{\Delta(x)}$$

# %%
x = np.linspace(-10, 10, 1000)
y = x ** 2
y_prime = 2 * x
fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(x, y, label='f')
ax.plot(x, y_prime, label='f prime')
ax.legend();

# %%
from IPython.display import Image
Image('derivatives.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1271         try:
# -> 1272             b64_data = b2a_base64(self.data).decode('ascii')
#    1273         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %% [markdown]
# Нахождение значения функции в окрестности $x_0$ через производную:

# %% [markdown]
# $$f'(x_0) \sim \frac{y - y_0}{x - x_0} \implies y - y_0 \sim f'(x_0)(x - x_0) \implies y \sim y_0 + f'(x_0)(x - x_0)$$

# %% [markdown]
# ## 4. Монотонность и выпуклость

# %% [markdown]
# ### Монотонность и выпуклость

# %% [markdown]
# Монотонная функция – все время либо не убывает, либо не возрастает. Если всегда либо растет, либо убывает, то функция – строго монотонная.
# $e^x$ – строго монотонная.
# $x^2$ – не монотонная.

# %% [markdown]
# Выпуклая функция - та, для которой выполняется неравенство Йенсена:
# $$f(t\cdot x_1 + (1 - t)\cdot x_2) \leq t \cdot f(x_1) + (1 - t) \cdot f(x_2),$$
# $$x_1,\space x_2 \space – \space значения \space аргумента \space функции, t \in [0, 1]$$

# %% [markdown]
# Если человеческим языком, то к любой точке функции можно провести касательную и вся функция будет находиться только с одной стороны от касательной. Тогда функция выпуклая.

# %% [markdown]
# ### Нули производной

# %% [markdown]
# Нули производной – это точки экстремума (максимума или минимума) функции, или точки ее перегиба.

# %%
x = np.linspace(-10, 10, 1000)
y = x ** 2
fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(x, y)
y_min = np.min(y)
x_min_pos = list(y).index(y_min)
x_min = np.array(x)[x_min_pos]
ax.plot(x_min, y_min, 'ro')
ax.text(x_min, y_min + 10, 'точка минимума для x^2');

# %%
x = np.linspace(-10, 10, 1000)
y = x ** 3
fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(x, y)
ax.plot(0, 0, 'ro')
ax.text(0, 0 - 200, 'точка перегиба для x^3');

# %% [markdown]
# ### Периоды монотонности

# %% [markdown]
# Промежутки между нулями производной – периоды монотонности

# %%
x = np.linspace(-10, 10, 1000)
y = 3 * x ** 3 - 2 * x ** 2 + x - 5
y_prime = 9 * x ** 2 - 4 * x + 1
fig, ax = plt.subplots(figsize=(12, 10))

ax.plot(x, y, label='f')
ax.plot(x, y_prime, label='f prime')
zero_prime_coord = np.where(np.isclose(y_prime, 0, atol=1e-00))[0]
for x_coord in zero_prime_coord:
    ax.plot(x[x_coord], y_prime[x_coord], 'ro')

plt.legend();

# %%
np.where(np.isclose(y_prime, 0, atol=1e-00))
# Out:
# (array([500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512,
#         513, 514, 515, 516, 517, 518, 519, 520, 521]),)

# %%
x = np.linspace(-10, 10, 1000)
y = np.sin(x)
y_prime = np.cos(x)
fig, ax = plt.subplots(figsize=(12, 10))
ax.plot(x, y, label='f')
ax.plot(x, y_prime, label='f prime')
zero_prime_coord = np.where(np.isclose(y_prime, 0, atol=1e-02))[0]
for x_coord in zero_prime_coord:
    ax.plot(x[x_coord], y_prime[x_coord], 'ro')
plt.legend();

# %% [markdown]
# Период монотонности:

# %%
x[zero_prime_coord[1]] - x[zero_prime_coord[0]]
# Out:
# 3.143143143143143

# %% [markdown]
# Период монотонности – $\pi$

# %% [markdown]
# ## 5. Функции многих переменных

# %% [markdown]
# ## $f(x, y)$

# %% [markdown]
# Все то же самое, что в обычных функциях, но отличается область определения, так как аргументов несколько.

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection='3d')
n = 10
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
z = [np.sin(x_val) * (y_val) ** 2 for x_val, y_val in zip(x, y)]

ax.scatter(x, y, z)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')

plt.show()

# %% [markdown]
# $$z = f(x, y) = sin(x) + y^2$$

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-3.0, 3.0, 0.05)
x, y = np.meshgrid(x, y)
z = np.array([np.sin(x) + y ** 2 for x, y in zip(np.ravel(x), np.ravel(y))])
z = z.reshape(x.shape)

ax.plot_surface(x, y, z, cmap='inferno')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('f(x, y)')

plt.show()

# %% [markdown]
# ### Метрики

# %% [markdown]
# У модели множество параметров – входных значений, и один результат. Метрики – агрегирующие функции

# %% [markdown]
# MSE

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# $$\sum (y_{true} - y_{pred})^2$$

# %%
y_true = [120, 10, 300]
y_pred = [90, 83, 300]
mean_squared_error(y_true, y_pred)
# Out:
# 2076.3333333333335

# %% [markdown]
# Binary cross-entropy

# %%
from sklearn.metrics import log_loss

# %%
y_true = [1, 0, 0]
y_pred = [0.9, 0.8, 0.1]
log_loss(y_true, y_pred)
# Out:
# 0.6067196479165844

# %% [markdown]
# ### Частные производные

# %% [markdown]
# Для функции от нескольких переменных можно считать производную двумя способами – частные производные и градиент.
# При частной производной мы считаем все переменные кроме одной – константами, по оставшейся дифференцируем.

# %% [markdown]
# $$f(x, y) = x^2 \cdot e^y + 2y^3 \cdot x$$
# $$f'_x = 2x \cdot e^y + 2y^3$$
# $$f'_y = x^2 \cdot e^y + 6y^2 \cdot x$$

# %% [markdown]
# Второй способ – градиент. Берем все частные производные, составляем вектор значений из них:

# %% [markdown]
# $$\nabla f(x, y) = (2x \cdot e^y + 2y^3, x^2 \cdot e^y + 6y^2 \cdot x)$$

# %% [markdown]
# Функция растёт быстрее всего в направлении градиента, убывает в противоположном направлении.
# Это значит, что для минимизации функции можно делать [маленькие шаги](https://en.wikipedia.org/wiki/Learning_rate) в направлении антиградиента, см. [стохастический градиентный спуск](http://www.machinelearning.ru/wiki/index.php?title=%D0%A1%D1%82%D0%BE%D1%85%D0%B0%D1%81%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B9_%D0%B3%D1%80%D0%B0%D0%B4%D0%B8%D0%B5%D0%BD%D1%82%D0%BD%D1%8B%D0%B9_%D1%81%D0%BF%D1%83%D1%81%D0%BA).

# %% [markdown]
# Гессиан - матрица вторых производных (по всем парам, поэтому матрица, а не вектор).
# Если она положительно определена, а градиент равен нулю, то это точка минимума. Используется в оптимизации, см. [метод Ньютона](https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%9D%D1%8C%D1%8E%D1%82%D0%BE%D0%BD%D0%B0).

# %% [markdown]
# ![hessian.png](data:image/png;base64,...)![](./hessian.png)

# %% [markdown]
# $$H(f) = \begin{pmatrix} 2 \cdot e^y &&  2x \cdot e^y + 6y^2 \\ 2x \cdot e^y && x^2 \cdot e^y + 12y \end{pmatrix}$$

# %%
random_data = np.random.randn(10, 10)

# %%
from scipy.ndimage.filters import laplace

# %%
xx, yy = np.mgrid[:200, :200]
circle_data = (xx - 100) ** 2 + (yy - 100) ** 2
circle = np.logical_and(circle_data < (6400 + 60), circle_data > (6400 - 60))

# %%
plt.imshow(circle)

# %%
plt.imshow(laplace(circle))

# %% [markdown]
# С практики в miro:
# ![](./linear.png)![linear.png](data:image/png;base64,...)

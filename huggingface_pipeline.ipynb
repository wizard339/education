# %% [markdown]
# <a href="https://colab.research.google.com/github/wizard339/education/blob/main/huggingface_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers > /dev/null

# %%
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 17.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=78646f53ad5261e2baeb9e4dd1b8e83f7aa3eae5996b4c5a328539b8599b3e1c
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# ...

# %%
# !pip install codecarbon
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.9/174.9 KB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 4.7 MB/s eta 0:00:00
# ...

# %%
from codecarbon import track_emissions

# %%
from transformers import pipeline

# %% [markdown]
# Пример тематической классификации с помощью предобученной модели на датасете Ag-News с сайта Hugging Face
#
# https://huggingface.co/models?pipeline_tag=text-classification&dataset=dataset:ag_news&language=en&sort=downloads

# %%
cls_pl = pipeline('text-classification', 'mrm8488/bert-mini-finetuned-age_news-classification')
cls_pl('NLP is a field of linguistics and machine learning focused on understanding everything related to human language')
# Out:
# ...
# [{'label': 'Sci/Tech', 'score': 0.9714405536651611}]

# %% [markdown]
# Перевод с русского на английский

# %%
en_ru_translate = pipeline('translation_ru_to_en', "facebook/wmt19-ru-en")
en_ru_translate('Сегодня был просто прекрасный день: у меня не завелась машина, и я опоздал на работу.')
# Out:
# ...
# [{'translation_text': "Today was just a great day: I didn't have a car and I was late for work."}]

# %% [markdown]
# Перевод с английского на русский

# %%
ru_en_translate = pipeline('translation_ru_to_en', "facebook/wmt19-en-ru")
ru_en_translate("Today was just a great day: I didn't have a car and I was late for work.")
# Out:
# ...
# [{'translation_text': 'Сегодня был просто замечательный день: у меня не было машины, я опаздывал на работу.'}]

# %% [markdown]
# Аннотация

# %%
sum_pipeline = pipeline("summarization", "IlyaGusev/rut5_base_sum_gazeta")

sum_pipeline("Естественным развитием задач классификации всего текста или его фрагментов является классификация отдельных слов в предложении. Наиболее распространенной задачей такого вида является задача выделения именованных сущностей (NER - named entity recognition) - в данном случае необходимо для каждого слова в тексте проставить класс принадлежности его к тому или иному типу сущности (например, организация, персона, локация и т.д.), либо пустой класс, показывающий, что слово не относится ни к одному из рассматриваемых классов. С помощью NER можно разрабатывать системы автоматического заполнения форм документов, составления отчетов о компаниях, нахождения разных упоминания одних и тех же сущностей (это задача entity linking - она решается после ner), удаления персональной информации из текстов и т.д. Кроме классификации слов текста на именованные сущности, можно производить классификацию по каким-то другим критериям - например, по частям речи (хотя это практическое использование такого рода задач гораздо уже).")
# Out:
# ...
# [{'summary_text': 'Задача классификации всего текста или его фрагментов является задачей выделения именованных сущностей (NER), которая позволяет разрабатывать системы автоматического заполнения форм документов, составления отчетов о компаниях, удаления персональной информации из текстов и т.д.'}]

# %% [markdown]
# Поиск ответа на вопрос

# %%
qa_pipeline = pipeline("question-answering", "AlexKay/xlm-roberta-large-qa-multilingual-finedtuned-ru")
question = "Which name is also used to describe the Amazon rainforest in English?"

context = "The Amazon rainforest (Portuguese: Floresta Amazônica or Amazônia; Spanish: Selva Amazónica, Amazonía or usually Amazonia; French: Forêt amazonienne; Dutch: Amazoneregenwoud), also known in English as Amazonia or the Amazon Jungle, is a moist broadleaf forest that covers most of the Amazon basin of South America. This basin encompasses 7,000,000 square kilometres (2,700,000 sq mi), of which 5,500,000 square kilometres (2,100,000 sq mi) are covered by the rainforest. This region includes territory belonging to nine nations. The majority of the forest is contained within Brazil, with 60% of the rainforest, followed by Peru with 13%, Colombia with 10%, and with minor amounts in Venezuela, Ecuador, Bolivia, Guyana, Suriname and French Guiana. States or departments in four nations contain \"Amazonas\" in their names. The Amazon represents over half of the planet's remaining rainforests, and comprises the largest and most biodiverse tract of tropical rainforest in the world, with an estimated 390 billion individual trees divided into 16,000 species."
qa_pipeline(question, context)
# Out:
# ...
# {'score': 0.47346293926239014,
#  'start': 200,
#  'end': 231,
#  'answer': ' Amazonia or the Amazon Jungle,'}

# %%
with open('/content/text1.txt', mode='r') as f:
  our_context = f.read()

# %%
q1 = 'Какая задача может быть развитием задачи классификации текстов?'
q2 = 'Что послужило основным толчком для существенного улучшения качества решения NLP-задач в последние несколько лет?'
q3 = 'Что служит входными данными для задачи поиска ответа на вопрос в заданном контексте?'
q4 = 'Какие NLP-задачи успешно решались с использованием классических статистических методов?'

# %%
qa_pipeline(q1, our_context)
# Out:
# {'score': 0.8945214152336121,
#  'start': 16174,
#  'end': 16218,
#  'answer': ' классификация отдельных слов в предложении.'}

# %%
qa_pipeline(q2, our_context)
# Out:
# {'score': 0.7407586574554443,
#  'start': 17802,
#  'end': 17824,
#  'answer': '\nРазвитие NLP-подходов'}

# %%
qa_pipeline(q3, our_context)
# Out:
# {'score': 0.5841923356056213,
#  'start': 1193,
#  'end': 1231,
#  'answer': ' сформулированный пользователем вопрос'}

# %%
qa_pipeline(q4, our_context)
# Out:
# {'score': 0.6388611793518066,
#  'start': 1788,
#  'end': 1830,
#  'answer': ' различные варианты классификации текстов.'}

# %%
ner_pipeline = pipeline("ner", "dslim/bert-base-NER", aggregation_strategy="first")
ner_pipeline("Matthew Carrigan is a Machine Learning Engineer at Hugging Face. He lives in Dublin, Ireland and previously worked as an ML engineer at Parse.ly and before that as a post-doctoral researcher at Trinity College Dublin.")
# Out:
# ...
# [{'entity_group': 'PER',
#   'score': 0.9996791,
#   'word': 'Matthew Carrigan',
#   'start': 0,
#   'end': 16},
#  {'entity_group': 'ORG',
#   'score': 0.9857482,
#   'word': 'Hugging Face',
#   'start': 51,
#   'end': 63},
#  {'entity_group': 'LOC',
#   'score': 0.9993766,
#   'word': 'Dublin',
#   'start': 77,
#   'end': 83},
#  {'entity_group': 'LOC',
#   'score': 0.9996132,
#   'word': 'Ireland',
#   'start': 85,
#   'end': 92},
#  {'entity_group': 'ORG',
#   'score': 0.84308773,
#   'word': 'ML',
#   'start': 121,
#   'end': 123},
#  {'entity_group': 'ORG',
#   'score': 0.94738454,
#   'word': 'Parse. ly',
#   'start': 136,
#   'end': 144},
#  {'entity_group': 'ORG',
#   'score': 0.9977536,
#   'word': 'Trinity College Dublin',
#   'start': 194,
#   'end': 216}]

# %%
@track_emissions()
def test_func():
    ner_pipeline = pipeline("ner", "dslim/bert-base-NER", aggregation_strategy="first")
    return ner_pipeline("Matthew Carrigan is a Machine Learning Engineer at Hugging Face. He lives in Dublin, Ireland and previously worked as an ML engineer at Parse.ly and before that as a post-doctoral researcher at Trinity College Dublin.")

# %%
test_func()
# Out:
# [codecarbon INFO @ 18:55:14] [setup] RAM Tracking...
# [codecarbon INFO @ 18:55:14] [setup] GPU Tracking...
# [codecarbon INFO @ 18:55:14] No GPU found.
# [codecarbon INFO @ 18:55:14] [setup] CPU Tracking...
# [codecarbon WARNING @ 18:55:14] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 18:55:16] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 18:55:16] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 18:55:16] >>> Tracker's metadata:
# [codecarbon INFO @ 18:55:16]   Platform system: Linux-5.10.147+-x86_64-with-glibc2.29
# [codecarbon INFO @ 18:55:16]   Python version: 3.8.10
# [codecarbon INFO @ 18:55:16]   Available RAM : 12.681 GB
# [codecarbon INFO @ 18:55:16]   CPU count: 2
# [codecarbon INFO @ 18:55:16]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 18:55:16]   GPU count: None
# ...
